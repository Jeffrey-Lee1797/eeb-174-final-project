# %% [markdown]
# # Introduction
#
# The Canidae family consists of three subfamilies (Hesperocyoninae, Borophaginae, and Caninae) with a fossil record spanning the past 40 million years (Finarelli et al. 2007). There exists more than 120 fossil taxa consisting of these three subfamilies. The Hesperocyoninae and Borophaginae subfamilies are both entirely extinict; all extant species belong to the Caninae subfamily (Finarelli 2013). Canids are found on every continent except Antartica and can vary in size from a few pounds to over a hundred pounds (Keliman 1967). This diversity is due to a lack of specialization and a strong ability to adapt to various environments.
#
#     Finarelli, John A., and Anjali Goswami. “Potential Pitfalls of Reconstructing Deep Time Evolutionary History With Only Extant Data, A Case Study Using The Canidae (Mammalia, Carnivora).” Evolution, vol. 67, no. 12, 2013, pp. 3678–3685.
#
#     Finarelli, John A., et al. “Mechanisms behind Active Trends in Body Size Evolution of the Canidae (Carnivora: Mammalia).” The American Naturalist, vol. 170, no. 6, 2007, pp. 876–885.
#
#     Kleiman, Devra G. “Some Aspects of Social Behavior in the Canidae.” American Zoologist, vol. 7, no. 2, 1967, pp. 365–372.

# %% [markdown]
# # The following was done in the shell terminal:
#
# I downloaded the files from paleobiology database into my downloads file. I then moved it into my final project folder:
#
#     cp ~/Downloads/pbdb_data.csv ~/Desktop/EEB-177/eeb-174-final-project
#
# I then renamed it so that it would be easier to identify the species I was working with:
#
#     mv pbdb_data.csv Canidae_data.csv
#
# I then checked the number of unique species using:
#
#     tail -n +19 Canidae_data.csv | cut -d "," f 6 | sort | uniq | wc -l

# %% [markdown]
# # The following was done in the Python Notebook:

# %% [markdown]
# ### Made a dictionary containing the name of the species and the age of the fossil

# %%
# Making a dictionary for Canidae
def makeCanidaeDict(filename):
    Canidae_dict = {} # Creates an empty dictionary 
    Canidae_species = open(filename, "r", encoding = "ISO-8859-15") # Will open the data file
    Canidae_records = Canidae_species.readlines()[19:] # This will read the file after line 19 which excludes the heading
    for line in Canidae_records:
        line = line.replace('\"', '') # Removes the extra quotes
#         #line = line.replace('\'', '')
        record_elements = line.split(",") # Denotes that each record element is separated by a file
        species = record_elements[5] # Making species be the keys and taking the names from column 5
        max_age = float(record_elements[14]) # Assigning max age to column 14
        min_age = float(record_elements[15]) # Assigning min age to column 15
        #age = max_age
        age = max_age - min_age # Calculating the age of the fossil
        Canidae_dict[species] = age # Assigning the age as the values in the dictionary
        #print(record_elements)
    return Canidae_dict

# %% [markdown]
# ### Made a dictionary containing the name of the species and the first occurance of the fossil

# %%
# Make a dictionary for the species and first occurance 
#sorted(mydict.items(), key=lambda x: x[1]) #sorts the dictionary numerically by values
def FirstOccurance(filename):
    firstOccurance_dict = {} # Create an empty dictionary 
    species_data = open(filename, "r", encoding = "ISO-8859-15") # Open file
    firstOccurance_records = species_data.readlines()[19:] # Read the file
    for line in firstOccurance_records:
        line = line.replace('\"', '') 
        firstOccurance_elements = line.split(",")
        species = firstOccurance_elements[5] # Populate the species with the data in column 6
        start_year = float(firstOccurance_elements[14]) # Populate the start year with data from column 15
        firstOccurance_dict[species] = start_year # Assign species as keys and start year as values
    return firstOccurance_dict

fo_dict = FirstOccurance("Canidae_data.csv")

# %% [markdown]
# ### Made a dictionary containing the name of the species and the last occurance of the fossil

# %%
# Create a dictionary of last occurances
def LastOccurance(filename):
    lastOccurance_dict = {} # Crete an empty dictionary 
    rspecies_data = open(filename, "r", encoding = "ISO-8859-15") # Open file
    lastOccurance_records = rspecies_data.readlines()[19:] # Read the file
    for line in lastOccurance_records:
        line = line.replace('\"', '') 
        lastOccurance_elements = line.split(",")
        species = lastOccurance_elements[5] # Populate the species with the data in column 6
        end_year = float(lastOccurance_elements[15]) # Populate the end year with data from column 16 
        lastOccurance_dict[species] = end_year # Assign species as keys and end year as values
    return lastOccurance_dict

lo_dict = LastOccurance("Canidae_data.csv")

# %% [markdown]
# ### Made a dictionary containing the name of the species as well as both the first and last occurances

# %%
# Create a combined dictionary in which each key (species) has both first and last occurances as values
from collections import defaultdict

combined_dict = defaultdict(list) # Create lists for values within dictionary

for d in (fo_dict, lo_dict):
    for key, value in d.items():
        combined_dict[key].append(value) # Append both values as a list for each key in a new combined dictionary

combined_dict
# Out:
# defaultdict(list,
#             {'Aelurodon ? sp.': [13.6, 4.9],
#              'Aelurodon asthenostylus': [15.97, 13.6],
#              'Aelurodon cf. ferox': [15.97, 13.6],
#              'Aelurodon cf. taxoides': [13.6, 10.3],
#              'Aelurodon cf. wheelerianus': [20.43, 15.97],
#              'Aelurodon ferox': [15.97, 13.6],
#              'Aelurodon mcgrewi': [15.97, 13.6],
#              'Aelurodon n. sp. mcgrewi': [15.97, 13.6],
#              'Aelurodon n. sp. montanensis': [15.97, 13.6],
#              'Aelurodon sp.': [13.6, 10.3],
#              'Aelurodon stirtoni': [15.97, 13.6],
#              'Aelurodon taxoides': [13.6, 10.3],
#              'Aenocyon ayersi': [0.126, 0.0117],
#              'Aenocyon ayersi ?': [2.588, 0.0117],
#              'Aenocyon cf. ayersi': [0.126, 0.0117],
#              'Aenocyon cf. dirus': [0.126, 0.0117],
#              'Aenocyon dirus': [0.126, 0.0117],
#              'Aenocyon sp.': [0.126, 0.0117],
#              'Alopex cf. lagopus': [1.8, 0.3],
#              'Alopex lagopus': [0.0117, 0.0],
#              'Alopex praeglacialis ?': [5.333, 0.0117],
#              'Archaeocyon falkenbachi': [30.8, 20.43],
#              'Archaeocyon leptodus': [30.8, 20.43],
#              'Archaeocyon pavidus': [30.8, 26.3],
#              'Borophaginae indet.': [20.43, 15.97],
#              'Borophagus ? sp.': [10.3, 4.9],
#              'Borophagus cf. diversidens': [4.9, 1.8],
#              'Borophagus cf. dudleyi': [5.333, 3.6],
#              'Borophagus cf. hilli': [4.9, 1.8],
#              'Borophagus cf. littoralis': [13.6, 10.3],
#              'Borophagus cf. orc': [5.333, 3.6],
#              'Borophagus cf. pugnator': [23.03, 5.333],
#              'Borophagus cf. secundus': [10.3, 4.9],
#              'Borophagus diversidens': [4.9, 1.8],
#              'Borophagus hilli': [4.9, 1.8],
#              'Borophagus littoralis': [23.03, 5.333],
#              'Borophagus n. sp. hilli': [10.3, 4.9],
#              'Borophagus n. sp. littoralis': [23.03, 5.333],
#              'Borophagus n. sp. parvus': [10.3, 4.9],
#              'Borophagus orc': [10.3, 4.9],
#              'Borophagus parvus': [10.3, 4.9],
#              'Borophagus pugnator': [13.6, 10.3],
#              'Borophagus secundus': [10.3, 4.9],
#              'Borophagus sp.': [13.6, 4.9],
#              'Caedocyon n. sp. tedfordi': [30.8, 20.43],
#              'Canidae ? indet.': [15.97, 13.6],
#              'Canidae indet.': [2.588, 0.781],
#              'Canidae informal indet. large': [2.588, 0.0117],
#              'Canidae sp.': [0.126, 0.0117],
#              'Caninae indet.': [2.588, 0.0117],
#              'Canini indet.': [4.9, 1.8],
#              'Canis (Thos ?) sp.': [2.588, 0.781],
#              'Canis (Xenocyon) falconeri': [2.588, 0.0117],
#              'Canis (Xenocyon) lycaonoides': [2.588, 0.781],
#              'Canis (Xenocyon) sp.': [2.588, 0.781],
#              'Canis ? latrans': [1.8, 0.3],
#              'Canis adustus': [2.588, 0.0117],
#              'Canis aff. adustus': [0.781, 0.126],
#              'Canis aff. arnensis': [2.588, 0.781],
#              'Canis aff. aureus': [2.588, 0.0117],
#              'Canis aff. etruscus': [2.588, 1.806],
#              'Canis aff. lupus': [3.6, 2.588],
#              'Canis andersoni': [0.3, 0.012],
#              'Canis anthus': [2.588, 0.0],
#              'Canis armbrusteri': [1.8, 0.3],
#              'Canis arnensis': [2.588, 0.126],
#              'Canis aureus': [0.0117, 0.0],
#              'Canis aureus ?': [0.781, 0.126],
#              'Canis avus': [0.126, 0.0117],
#              'Canis ayersi': [0.126, 0.0117],
#              'Canis brevirostris': [5.333, 0.781],
#              'Canis cf. adustus': [3.6, 2.588],
#              'Canis cf. dirus': [0.126, 0.0117],
#              'Canis cf. edwardii': [1.8, 0.3],
#              'Canis cf. etruscus': [5.333, 0.0117],
#              'Canis cf. falconeri': [2.588, 0.126],
#              'Canis cf. ferox': [10.3, 4.9],
#              'Canis cf. kronstadtensis': [0.781, 0.126],
#              'Canis cf. latrans': [0.126, 0.0117],
#              'Canis cf. lepophagus': [4.9, 1.8],
#              'Canis cf. lupaster': [2.588, 0.0117],
#              'Canis cf. lupus': [0.126, 0.0117],
#              'Canis cf. mesomelas': [2.588, 0.0117],
#              'Canis cf. mosbachensis': [0.781, 0.126],
#              'Canis cf. occidentalis': [0.126, 0.0117],
#              'Canis cf. priscolatrans': [1.8, 0.3],
#              'Canis cf. riviveronis': [0.126, 0.0117],
#              'Canis cf. senezensis': [5.333, 2.588],
#              'Canis cf. spelaeus': [0.781, 0.126],
#              'Canis cf. terblanchei': [1.806, 0.781],
#              'Canis cipio': [8.7, 5.333],
#              'Canis dirus': [1.8, 0.3],
#              'Canis edwardii': [4.9, 1.8],
#              'Canis etruscus': [11.608, 0.781],
#              'Canis ex gr. etruscus': [5.333, 0.0117],
#              'Canis falconeri': [2.588, 0.781],
#              'Canis familiaris': [0.0117, 0.0],
#              'Canis ferox': [4.9, 1.8],
#              'Canis indianensis': [0.126, 0.0117],
#              'Canis kuruksaensis': [5.333, 2.588],
#              'Canis latrans': [0.0117, 0.0],
#              'Canis latrans ?': [0.126, 0.0117],
#              'Canis lepophagus': [0.126, 0.0117],
#              'Canis lupes': [2.588, 0.0],
#              'Canis lupus': [0.126, 0.0117],
#              'Canis mesomelas': [2.588, 0.0117],
#              'Canis microdon': [0.126, 0.0117],
#              'Canis milleri': [0.3, 0.012],
#              'Canis mosbachensis': [2.588, 0.781],
#              'Canis mosbachensis ?': [2.588, 0.781],
#              'Canis n. sp. apolloniensis': [2.588, 0.781],
#              'Canis n. sp. armbrusteri': [1.8, 0.3],
#              'Canis n. sp. ayersi': [0.126, 0.0117],
#              'Canis n. sp. brachypus': [20.43, 15.97],
#              'Canis n. sp. cedazoensis': [1.8, 0.3],
#              'Canis n. sp. ferox': [10.3, 4.9],
#              'Canis n. sp. lepophagus': [4.9, 1.8],
#              'Canis n. sp. multicuspus': [5.333, 3.6],
#              'Canis n. sp. sp.': [0.781, 0.126],
#              'Canis n. sp. thooides': [4.9, 1.8],
#              'Canis nubilus': [0.126, 0.0117],
#              'Canis occidentalis': [0.0117, 0.0],
#              'Canis ochropus': [0.126, 0.0117],
#              'Canis ochropus ?': [2.588, 0.0117],
#              'Canis odessanus': [4.2, 2.588],
#              'Canis proplatensis': [2.588, 0.781],
#              'Canis rufus': [0.126, 0.0117],
#              'Canis sp.': [0.0117, 0.0],
#              'Canis tengisii': [2.588, 0.0117],
#              'Canis terblanchei': [5.333, 0.0117],
#              'Canis variabilis': [0.126, 0.0117],
#              'Canis vulpes ?': [2.588, 0.0117],
#              'Canis yuanmouensis': [2.588, 0.0117],
#              'Carpocyon compressus': [15.97, 13.6],
#              'Carpocyon limosus': [10.3, 4.9],
#              'Carpocyon n. sp. limosus': [10.3, 4.9],
#              'Carpocyon n. sp. webbi': [13.6, 10.3],
#              'Carpocyon robustus': [13.6, 10.3],
#              'Carpocyon sp.': [15.97, 13.6],
#              'Carpocyon webbi': [15.97, 13.6],
#              'Cerdocyon avius': [4.9, 1.8],
#              'Cerdocyon avius ?': [5.333, 2.588],
#              'Cerdocyon n. sp. texanus': [4.9, 1.8],
#              'Cerdocyon texanus': [10.3, 4.9],
#              'Cerdocyon thous': [0.126, 0.0],
#              'Chrysocyon brachyurus': [2.588, 0.0],
#              'Chrysocyon n. sp. nearcticus': [4.9, 1.8],
#              'Chrysocyon nearcticus': [4.9, 1.8],
#              'Chrysocyon sp.': [2.588, 0.0],
#              'Cormocyon cf. copei': [24.8, 20.43],
#              'Cormocyon copei': [26.3, 24.8],
#              'Cormocyon haydeni': [24.8, 20.43],
#              'Cormocyon n. sp. haydeni': [24.8, 20.43],
#              'Cormocyon sp.': [30.8, 26.3],
#              'Cuon ? sp.': [0.781, 0.126],
#              'Cuon alpinus': [0.126, 0.0117],
#              'Cuon cf. priscus': [0.781, 0.126],
#              'Cuon javanicus': [0.781, 0.126],
#              'Cuon priscus': [0.781, 0.126],
#              'Cuon sp.': [0.781, 0.126],
#              'Cuon stehlini': [0.781, 0.126],
#              'Cuon texanus': [1.8, 0.3],
#              'Cynarctoides acridens': [24.8, 20.43],
#              'Cynarctoides cf. acridens': [20.43, 15.97],
#              'Cynarctoides cf. luskensis': [30.8, 20.43],
#              'Cynarctoides emryi': [20.43, 15.97],
#              'Cynarctoides gawnae': [23.03, 5.333],
#              'Cynarctoides harlowi': [24.8, 20.43],
#              'Cynarctoides lemur': [24.8, 20.43],
#              'Cynarctoides luskensis': [24.8, 20.43],
#              'Cynarctoides n. sp. emryi': [20.43, 15.97],
#              'Cynarctoides n. sp. gawnae': [20.43, 15.97],
#              'Cynarctoides n. sp. luskensis': [24.8, 20.43],
#              'Cynarctoides n. sp. whistleri': [20.43, 15.97],
#              'Cynarctoides roii': [30.8, 26.3],
#              'Cynarctoides whistleri': [20.43, 15.97],
#              'Cynarctus cf. saxatilis': [15.97, 13.6],
#              'Cynarctus crucidens': [13.6, 4.9],
#              'Cynarctus galushai': [15.97, 13.6],
#              'Cynarctus marylandica': [15.97, 13.82],
#              'Cynarctus n. sp. crucidens': [13.6, 10.3],
#              'Cynarctus n. sp. galushai': [15.97, 13.6],
#              'Cynarctus n. sp. voorhiesi': [13.6, 10.3],
#              'Cynarctus n. sp. wangi': [15.97, 13.6],
#              'Cynarctus saxatilis': [15.97, 13.6],
#              'Cynarctus sp.': [23.03, 5.333],
#              'Cynarctus voorhiesi': [13.6, 10.3],
#              'Cynodesmus n. sp. martini': [30.8, 20.43],
#              'Cynodesmus n. sp. thooides': [30.8, 20.43],
#              'Cynodesmus thooides': [30.8, 26.3],
#              'Cynodictis informal sp.1': [38.0, 33.9],
#              'Cynodictis informal sp.2': [38.0, 33.9],
#              'Cynodictis lacustris': [38.0, 33.9],
#              'Cynodictis palmidens': [33.9, 28.4],
#              'Cynodictis sp.': [55.8, 48.6],
#              'Cynotherium ? sp.': [2.588, 0.126],
#              'Cynotherium sardous': [0.781, 0.0117],
#              'Cynotherium sp.': [3.6, 0.0117],
#              'Desmocyon matthewi': [20.43, 15.97],
#              'Desmocyon thomsoni': [20.43, 15.97],
#              'Dusicyon avus': [0.781, 0.012],
#              'Dusicyon cf. avus': [0.126, 0.0117],
#              'Dusicyon culpaeus': [2.588, 0.0117],
#              'Dusicyon griseus': [0.0117, 0.0],
#              'Dusicyon sechurae': [0.781, 0.0117],
#              'Dusicyon sp.': [2.588, 0.0117],
#              'Ectopocynus antiquus': [33.3, 30.8],
#              'Ectopocynus n. sp. antiquus': [30.8, 20.43],
#              'Ectopocynus n. sp. intermedius': [30.8, 20.43],
#              'Ectopocynus n. sp. simplicidens': [20.43, 15.97],
#              'Ectopocynus simplicidens': [20.43, 15.97],
#              'Enhydrocyon basilatus': [24.8, 20.43],
#              'Enhydrocyon cf. pahinsintewakpa': [30.8, 20.43],
#              'Enhydrocyon crassidens': [24.8, 20.43],
#              'Enhydrocyon n. sp. crassidens': [26.3, 24.8],
#              'Enhydrocyon pahinsintewakpa': [26.3, 24.8],
#              'Enhydrocyon prolatus': [33.3, 30.8],
#              'Enhydrocyon sp.': [26.3, 24.8],
#              'Enhydrocyon stenocephalus': [30.8, 20.43],
#              'Epicyon aff. haydeni': [13.6, 10.3],
#              'Epicyon cf. haydeni': [23.03, 5.333],
#              'Epicyon cf. saevus': [13.6, 10.3],
#              'Epicyon haydeni': [23.03, 5.333],
#              'Epicyon n. sp. aelurodontoides': [10.3, 4.9],
#              'Epicyon saevus': [23.03, 5.333],
#              'Epicyon sp.': [10.3, 4.9],
#              'Eucyon cf. davisi': [10.3, 4.9],
#              'Eucyon davisi': [10.3, 4.9],
#              'Eucyon monticinensis': [11.608, 5.333],
#              'Eucyon n. sp. skinneri': [13.6, 10.3],
#              'Eucyon sp.': [5.333, 2.588],
#              'Euoplocyon brachygnathus': [15.97, 13.6],
#              'Euoplocyon spissidens': [20.43, 15.97],
#              'Gobicyon macrognathus': [15.97, 5.333],
#              'Gobicyon sp.': [13.82, 11.62],
#              'Hesperocyon ? sp.': [33.3, 30.8],
#              'Hesperocyon cf. gregarius': [37.2, 33.9],
#              'Hesperocyon coloradensis': [33.9, 33.3],
#              'Hesperocyon gregarius': [33.9, 33.3],
#              'Hesperocyon paterculus': [37.2, 33.9],
#              'Hesperocyon sp.': [30.8, 20.43],
#              'Hesperocyoninae indet.': [24.8, 20.43],
#              'Hyaenognathus n. sp. cyonoides': [10.3, 4.9],
#              'Leptocyon ? sp.': [13.6, 10.3],
#              'Leptocyon cf. gregorii': [24.8, 20.43],
#              'Leptocyon cf. vafer': [15.97, 13.6],
#              'Leptocyon douglassi': [30.8, 20.43],
#              'Leptocyon gregorii': [24.8, 20.43],
#              'Leptocyon leidyi': [15.97, 13.6],
#              'Leptocyon matthewi': [13.6, 10.3],
#              'Leptocyon mollis': [30.8, 20.43],
#              'Leptocyon n. sp. douglassi': [30.8, 20.43],
#              'Leptocyon n. sp. leidyi': [20.43, 15.97],
#              'Leptocyon n. sp. matthewi': [13.6, 10.3],
#              'Leptocyon n. sp. tejonensis': [13.6, 10.3],
#              'Leptocyon sp.': [15.97, 13.6],
#              'Leptocyon vafer': [13.6, 10.3],
#              'Leptocyon vulpinus': [30.8, 20.43],
#              'Lycaon cf. magnus': [0.781, 0.126],
#              'Lycaon pictus': [0.126, 0.0117],
#              'Lycaon sp.': [3.6, 2.588],
#              'Mesocyon ? sp.': [30.8, 20.43],
#              'Mesocyon brachyops': [30.8, 20.43],
#              'Mesocyon cf. temnodon': [30.8, 26.3],
#              'Mesocyon coryphaeus': [30.8, 20.43],
#              'Mesocyon temnodon': [24.8, 20.43],
#              'Metalopex macconnelli': [23.03, 5.333],
#              'Metalopex merriami': [23.03, 5.333],
#              'Metalopex n. sp. bakeri': [10.3, 4.9],
#              'Metatomarctus canavus': [20.43, 15.97],
#              'Metatomarctus cf. canavus': [20.43, 15.97],
#              'Metatomarctus sp.': [23.03, 5.333],
#              'Miacis washakius': [46.2, 40.4],
#              'Microtomarctus cf. conferta': [15.97, 13.6],
#              'Microtomarctus conferta': [15.97, 13.6],
#              'Neocynodesmus n. sp. delicatus': [30.8, 20.43],
#              'Nyctereutes abdeslami': [3.6, 2.588],
#              'Nyctereutes aff. donnezani': [8.7, 5.333],
#              'Nyctereutes cf. donnezani': [4.2, 3.2],
#              'Nyctereutes cf. sinensis': [2.588, 0.781],
#              'Nyctereutes cf. tingi': [5.333, 2.588],
#              'Nyctereutes donnezani': [5.333, 3.2],
#              'Nyctereutes megamastoides': [2.588, 0.781],
#              'Nyctereutes procyonoides': [0.126, 0.0117],
#              'Nyctereutes sinensis': [2.588, 0.0117],
#              'Nyctereutes sp.': [2.588, 0.781],
#              'Osbornodon brachypus': [24.8, 20.43],
#              'Osbornodon fricki': [15.97, 13.6],
#              'Osbornodon iamonensis': [20.43, 15.97],
#              'Osbornodon n. sp. fricki': [15.97, 13.6],
#              'Osbornodon n. sp. renjiei': [33.9, 33.3],
#              'Osbornodon n. sp. wangi': [30.8, 20.43],
#              'Osbornodon renjiei': [33.3, 30.8],
#              'Osbornodon scitulus': [20.43, 15.97],
#              'Osbornodon sesnoni': [30.8, 20.43],
#              'Osteoborus cf. cyonoides': [11.608, 5.333],
#              'Otarocyon cooki': [30.8, 26.3],
#              'Otarocyon macdonaldi': [33.9, 33.3],
#              'Otarocyon n. sp. macdonaldi': [33.9, 33.3],
#              'Otocyon megalotis': [0.126, 0.0117],
#              'Otocyon recki': [2.588, 0.0117],
#              'Otocyon sp.': [2.588, 0.0117],
#              'Oxetocyon cuspidatus': [33.3, 30.8],
#              'Oxetocyon n. sp. cuspidatus': [33.3, 30.8],
#              'Oxetocyon sp.': [33.3, 30.8],
#              'Paracynarctus cf. kelloggi': [15.97, 13.6],
#              'Paracynarctus kelloggi': [15.97, 13.6],
#              'Paracynarctus n. sp. sinclairi': [20.43, 15.97],
#              'Paracynarctus sinclairi': [15.97, 13.6],
#              'Paraenhydrocyon josephi': [24.8, 20.43],
#              'Paraenhydrocyon robustus': [24.8, 20.43],
#              'Paraenhydrocyon wallovianus': [30.8, 20.43],
#              'Paratomarctus cf. temerarius': [15.97, 13.82],
#              'Paratomarctus euthos': [13.6, 10.3],
#              'Paratomarctus temerarius': [15.97, 13.6],
#              'Parenhydrocyon josephi': [26.3, 24.8],
#              'Philotrox condoni': [30.8, 20.43],
#              'Phlaocyon ? cf. annectens': [24.8, 20.43],
#              'Phlaocyon achoros': [24.8, 20.43],
#              'Phlaocyon annectens': [24.8, 20.43],
#              'Phlaocyon latidens': [30.8, 20.43],
#              'Phlaocyon leucosteus': [20.43, 15.97],
#              'Phlaocyon marslandensis': [20.43, 15.97],
#              'Phlaocyon minor': [20.43, 15.97],
#              'Phlaocyon multicuspus': [24.8, 20.43],
#              'Phlaocyon n. sp. leucosteus': [20.43, 15.97],
#              'Phlaocyon n. sp. mariae': [20.43, 15.97],
#              'Phlaocyon n. sp. taylori': [30.8, 20.43],
#              'Phlaocyon n. sp. yatkolai': [20.43, 15.97],
#              'Phlaocyon sp.': [30.8, 20.43],
#              'Phlaocyon taylori': [30.8, 20.43],
#              'Protepicyon n. sp. raki': [15.97, 13.6],
#              'Protepicyon raki': [15.97, 13.6],
#              'Protocyon orcesi': [0.781, 0.0117],
#              'Protocyon scagliaruen': [2.588, 0.0117],
#              'Protocyon sp.': [0.126, 0.0117],
#              'Protocyon tarijensis': [2.588, 0.781],
#              'Protocyon troglodytes': [0.126, 0.0],
#              'Protomarctus cf. optatus': [23.03, 5.333],
#              'Protomarctus optatus': [15.97, 13.6],
#              'Psalidocyon marianae': [20.43, 15.97],
#              'Psalidocyon n. sp. marianae': [15.97, 13.6],
#              'Pseudalopex (Dusicyon) sp.': [2.588, 0.0117],
#              'Pseudalopex aff. gymnocercus': [0.0117, 0.0],
#              'Pseudalopex griseus': [0.781, 0.012],
#              'Pseudalopex gymnocercus': [0.781, 0.012],
#              'Pseudalopex sp.': [0.781, 0.012],
#              'Rhizocyon oregonensis': [30.8, 20.43],
#              'Speothos sp.': [2.588, 0.0117],
#              'Speothos venaticus': [0.0117, 0.0],
#              'Sunkahetanka geringensis': [30.8, 26.3],
#              'Tephrocyon rurestris': [23.03, 5.333],
#              'Theriodictis floridanus ?': [4.9, 1.8],
#              'Theriodictis sp.': [1.2, 0.012],
#              'Theriodictis tarijensis': [2.588, 0.781],
#              'Tomarctus brevirostris': [15.97, 13.6],
#              'Tomarctus cf. hippophaga': [23.03, 5.333],
#              'Tomarctus cf. hippophagus': [23.03, 5.333],
#              'Tomarctus hippophaga': [15.97, 13.6],
#              'Tomarctus n. sp. brevirostris': [20.43, 15.97],
#              'Tomarctus n. sp. hippophaga': [20.43, 15.97],
#              'Tomarctus n. sp. marylandica': [20.44, 15.97],
#              'Tomarctus sp.': [13.6, 10.3],
#              'Urocyon californicus': [0.3, 0.012],
#              'Urocyon cf. cinereoargenteus': [0.126, 0.0117],
#              'Urocyon cinereoargenteus': [0.126, 0.0117],
#              'Urocyon galushai': [4.9, 1.8],
#              'Urocyon minicephalus': [1.8, 0.3],
#              'Urocyon n. sp. citrinus': [4.9, 1.8],
#              'Urocyon n. sp. galushai': [4.9, 1.8],
#              'Urocyon n. sp. minicephalus': [1.8, 0.3],
#              'Urocyon n. sp. webbi': [10.3, 4.9],
#              'Urocyon progressus': [4.9, 1.8],
#              'Urocyon sp.': [0.126, 0.0117],
#              'Urocyon townsendi': [0.126, 0.0117],
#              'Vulpes ? alopecoides': [3.2, 2.588],
#              'Vulpes ? sp.': [2.588, 0.781],
#              'Vulpes aff. donnezani': [5.333, 2.588],
#              'Vulpes aff. rueppelli': [3.6, 2.588],
#              'Vulpes alopecoides': [2.588, 0.781],
#              'Vulpes alopecoides ?': [5.333, 0.0117],
#              'Vulpes angustidens': [0.781, 0.126],
#              'Vulpes atlantica': [2.588, 0.0117],
#              'Vulpes cascadensis': [0.126, 0.0117],
#              'Vulpes cf. alopecoides': [5.333, 0.0117],
#              'Vulpes cf. angustidens': [0.781, 0.126],
#              'Vulpes cf. chikushanensis': [2.588, 0.0117],
#              'Vulpes cf. corsac': [2.588, 0.0117],
#              'Vulpes cf. praeglacialis': [2.588, 0.0117],
#              'Vulpes cf. stenognathus': [13.6, 4.9],
#              'Vulpes cf. velox': [0.126, 0.0117],
#              'Vulpes cf. vulpes': [0.781, 0.126],
#              'Vulpes chama': [2.588, 0.781],
#              'Vulpes fulva': [0.126, 0.0117],
#              'Vulpes fulvus': [0.0117, 0.0],
#              'Vulpes galaticus': [5.333, 3.2],
#              'Vulpes informal n. sp.': [4.9, 4.2],
#              'Vulpes macrotis': [0.126, 0.0117],
#              'Vulpes macroura': [0.126, 0.0117],
#              'Vulpes n. sp. kernensis': [13.6, 10.3],
#              'Vulpes n. sp. mathisoni': [5.333, 3.6],
#              'Vulpes n. sp. palmaria': [0.126, 0.0117],
#              'Vulpes n. sp. stenognathus': [10.3, 4.9],
#              'Vulpes palmaria': [0.126, 0.0117],
#              'Vulpes praecorsac': [4.2, 2.588],
#              'Vulpes praeglacialis': [0.781, 0.126],
#              'Vulpes praeglacialis ?': [3.2, 2.588],
#              'Vulpes pulcher': [5.333, 0.0117],
#              'Vulpes ruppellii': [2.588, 0.0117],
#              'Vulpes sp.': [0.126, 0.0117],
#              'Vulpes stenognathus': [15.97, 13.6],
#              'Vulpes velox': [0.126, 0.0117],
#              'Vulpes vinetorum': [2.588, 0.0117],
#              'Vulpes vulpes': [0.126, 0.0117],
#              'Vulpes vulpes ?': [3.2, 2.588],
#              'Vulpini indet.': [0.126, 0.0117],
#              'Xenocyon ? lycaonoides': [2.588, 0.0117],
#              'Xenocyon cf. lycanoides': [2.588, 0.0117],
#              'Xenocyon cf. lycaonoides': [0.781, 0.126],
#              'Xenocyon lycaonoides': [0.781, 0.126],
#              'Xenocyon sp.': [2.588, 0.781],
#              'Xenocyon spelaeoides': [0.781, 0.126],
#              'aff. Canis brevirostris': [5.333, 2.588],
#              'aff. Canis sp.': [2.588, 0.126],
#              'aff. Cynodictis sp.': [33.9, 28.4],
#              'aff. Phlaocyon sp.': [20.43, 15.97],
#              'cf. Aelurodon sp.': [15.97, 13.6],
#              'cf. Borophagus sp.': [4.9, 1.8],
#              'cf. Canidae indet.': [23.03, 2.588],
#              'cf. Canis brevirostris': [3.6, 2.588],
#              'cf. Canis mesomelas': [0.126, 0.0117],
#              'cf. Canis sp.': [5.333, 2.588],
#              'cf. Cuon stehlini': [0.781, 0.126],
#              'cf. Cynodictis lacustris': [38.0, 33.9],
#              'cf. Desmocyon sp.': [24.8, 20.43],
#              'cf. Dusicyon (Lycalopex) sp.': [0.126, 0.0117],
#              'cf. Eucyon davisi': [5.333, 3.6],
#              'cf. Eucyon sp.': [10.3, 4.9],
#              'cf. Leptocyon sp.': [30.8, 20.43],
#              'cf. Lycaon sp.': [2.588, 0.0117],
#              'cf. Nyctereutes megamastoides': [2.588, 0.781],
#              'cf. Nyctereutes sp.': [5.333, 3.6],
#              'cf. Otocyon sp.': [3.6, 2.588],
#              'cf. Paratomarctus temerarius': [15.97, 13.6],
#              'cf. Theriodictis sp.': [0.126, 0.0117],
#              'cf. Tomarctus sp.': [15.97, 13.82],
#              'cf. Urocyon sp.': [13.6, 10.3],
#              'cf. Vulpes chama': [2.588, 0.781],
#              'cf. Vulpes sp.': [5.333, 3.2],
#              'n. gen. Chailicyon n. sp. crassidens': [48.6, 37.2],
#              'n. gen. Cubacyon n. sp. transversidens': [2.588, 0.0],
#              'n. gen. Pachycyon n. sp. robustus': [0.0117, 0.0],
#              'n. gen. Protemnocyon n. sp. inflatus': [33.9, 33.3]})

# %% [markdown]
# ### Creating a CSV file to be used in RStudio

# %%
## Open the file

infile = "Canidae_data.csv"
with open(infile, 'r') as ff:
    canid_recs = ff.readlines()[1:]

# %%
# Make dictionary
from collections import defaultdict

species_range = defaultdict(list)

for line in canid_recs:
    species = line.split(",")[5]
    minage = line.split('","')[10]
    maxage = line.split('","')[11]
    
    mean_age = (float(minage) + float(maxage)) / 2
    
    # Add species as keys and mean ages as elements to the list of ages 
    species_range[species].append(mean_age)

# %%
output = open("Canidae-ranges.csv", "w")

for key in species_range.keys():
    ages = species_range[key]
    minage = min(ages)
    maxage = max(ages)
    genus = key.split(" ")[0]
    species = key
    outline = "{},{},{},{}\n".format(genus, species, minage, maxage)
    output.write(outline)

# %% [markdown]
# # The following was done in RStudio:

# %% [markdown]
# ### Read in the file
# ```{r}
# # Read in the file
# library(ggplot2)
# setwd("/home/eeb177-student/Desktop/EEB-177/eeb-174-final-project/project-deadline-6/")
#
# canids <- read.csv("/home/eeb177-student/Desktop/EEB-177/eeb-174-final-project/project-deadline-6/Canidae-ranges.csv", header =F, as.is = T)
#
# names(canids) <- c("genus", "species", "minage", "maxage")
# head(canids)
# ```
#
# ### Create the graph
# ```{r}
# Canidae_occ <- ggplot(canids, aes( species, ymin = maxage, ymax=minage, colour = genus))
# Canidae_occ <- Canidae_occ + geom_linerange()
# # Remove the legend
# Canidae_occ <- Canidae_occ + theme(legend.position="none")
# # Flip axis
# Canidae_occ <- Canidae_occ + coord_flip()
# # Change text size
# Canidae_occ <- Canidae_occ +  theme(axis.text.y = element_text(size=3))
# # Remove tick marks on y-axis
# Canidae_occ <- Canidae_occ + theme(axis.ticks.y=element_blank())
# # Remove excess white space
# Canidae_occ <- Canidae_occ + scale_y_continuous(limits=c(0, 40), expand = c(0, 0), breaks=c(0, 10, 20, 30, 40))
# # Add title and labels
# Canidae_occ <- Canidae_occ + labs(title = "Canidae Fossil Occurrences", x = "Species", y = "Ma ago") + theme(plot.title = element_text(hjust = 0.5, size=22, face = "bold"), axis.title =element_text(size=20))
# Canidae_occ
# ```
#
# ### Save the graphs as a pdf
# ```{r}
# ggsave(filename = "Canidae-occ.pdf", plot = Canidae_occ)
# ```

# %% [markdown]
# ## Link to Github: https://github.com/Jeffrey-Lee1797/eeb-174-final-project
